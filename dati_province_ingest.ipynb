# %% [markdown]
# ### Creating Covid_Italy Dataset

# %%
covid = "CovidItaly_staging"
# !bq --location=US mk --dataset {covid}
# Out:
# Dataset 'fluid-etching-266722:CovidItaly_staging' successfully created.

# %% [markdown]
# ### Making tables and sample records for each tables

# %% [markdown]
# Making a table for dpc-covid19-ita-province-20200324.csv and inspecting it

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --allow_quoted_newlines --allow_jagged_rows --quote ""\
--source_format=CSV {"CovidItaly_staging"}.dpc_covid19_ita_province_20200324 \
'gs://covid_es/dati_province/dpc-covid19-ita-province-20200324.csv'
# Out:
# Waiting on bqjob_r24ae49d7f7cb27b5_00000171fa485866_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select*from CovidItaly_staging.dpc_covid19_ita_province_20200324
# limit 5
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 0 2020-03-24 17:00:00+00:00   ITA               1              Piemonte
# 1 2020-03-24 17:00:00+00:00   ITA               1              Piemonte
# 2 2020-03-24 17:00:00+00:00   ITA               1              Piemonte
# 3 2020-03-24 17:00:00+00:00   ITA               1              Piemonte
# 4 2020-03-24 17:00:00+00:00   ITA               1              Piemonte
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                 6             Alessandria              AL  44.912974
# 1                 5                    Asti              AT  44.899129
# 2                96                  Biella              BI  45.566511
# 3                 4                   Cuneo              CN  44.393296
# 4                 3                  Novara              NO  45.445885
#
#        long  totale_casi note_it note_en
# 0  8.615401          946    None    None
# ...

# %% [markdown]
# Making a table for dpc-covid19-ita-province-20200325.csv and inspecting it

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --allow_quoted_newlines --allow_jagged_rows --quote ""\
--source_format=CSV {"CovidItaly_staging"}.dpc_covid19_ita_province_20200325 \
'gs://covid_es/dati_province/dpc-covid19-ita-province-20200325.csv'
# Out:
# Waiting on bqjob_r13f2f242b790f957_00000171fa487abc_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select*from CovidItaly_staging.dpc_covid19_ita_province_20200325
# limit 5
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 0 2020-03-25 17:00:00+00:00   ITA               1              Piemonte
# 1 2020-03-25 17:00:00+00:00   ITA               1              Piemonte
# 2 2020-03-25 17:00:00+00:00   ITA               1              Piemonte
# 3 2020-03-25 17:00:00+00:00   ITA               1              Piemonte
# 4 2020-03-25 17:00:00+00:00   ITA               1              Piemonte
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                 6             Alessandria              AL  44.912974
# 1                 5                    Asti              AT  44.899129
# 2                96                  Biella              BI  45.566511
# 3                 4                   Cuneo              CN  44.393296
# 4                 3                  Novara              NO  45.445885
#
#        long  totale_casi note_it note_en
# 0  8.615401          946    None    None
# ...

# %% [markdown]
# Making a table for dpc-covid19-ita-province-20200326.csv and inspecting it

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --allow_quoted_newlines --allow_jagged_rows --quote ""\
--source_format=CSV {"CovidItaly_staging"}.dpc_covid19_ita_province_20200326 \
'gs://covid_es/dati_province/dpc-covid19-ita-province-20200326.csv'
# Out:
# Waiting on bqjob_r67f845a293e05b29_00000171fa488cd3_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select*from CovidItaly_staging.dpc_covid19_ita_province_20200326
# limit 5
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 0 2020-03-26 17:00:00+00:00   ITA               1              Piemonte
# 1 2020-03-26 17:00:00+00:00   ITA               1              Piemonte
# 2 2020-03-26 17:00:00+00:00   ITA               1              Piemonte
# 3 2020-03-26 17:00:00+00:00   ITA               1              Piemonte
# 4 2020-03-26 17:00:00+00:00   ITA               1              Piemonte
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                 6             Alessandria              AL  44.912974
# 1                 5                    Asti              AT  44.899129
# 2                96                  Biella              BI  45.566511
# 3                 4                   Cuneo              CN  44.393296
# 4                 3                  Novara              NO  45.445885
#
#        long  totale_casi note_it note_en
# 0  8.615401          980    None    None
# ...

# %% [markdown]
# Making a table for dpc-covid19-ita-province-20200327.csv and inspecting it

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --allow_quoted_newlines --allow_jagged_rows --quote ""\
--source_format=CSV {"CovidItaly_staging"}.dpc_covid19_ita_province_20200327 \
'gs://covid_es/dati_province/dpc-covid19-ita-province-20200327.csv'
# Out:
# Waiting on bqjob_r190309ba352d5d83_00000171fa489f5f_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select*from CovidItaly_staging.dpc_covid19_ita_province_20200327
# limit 5
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 0 2020-03-27 17:00:00+00:00   ITA               1              Piemonte
# 1 2020-03-27 17:00:00+00:00   ITA               1              Piemonte
# 2 2020-03-27 17:00:00+00:00   ITA               1              Piemonte
# 3 2020-03-27 17:00:00+00:00   ITA               1              Piemonte
# 4 2020-03-27 17:00:00+00:00   ITA               1              Piemonte
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                 6             Alessandria              AL  44.912974
# 1                 5                    Asti              AT  44.899129
# 2                96                  Biella              BI  45.566511
# 3                 4                   Cuneo              CN  44.393296
# 4                 3                  Novara              NO  45.445885
#
#        long  totale_casi note_it note_en
# 0  8.615401         1106    None    None
# ...

# %% [markdown]
# Making a table for dpc-covid19-ita-province-20200328.csv and inspecting it

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 --allow_quoted_newlines --allow_jagged_rows --quote ""\
--source_format=CSV {"CovidItaly_staging"}.dpc_covid19_ita_province_20200328 \
'gs://covid_es/dati_province/dpc-covid19-ita-province-20200328.csv'
# Out:
# Waiting on bqjob_r5c231b04f6b954d8_00000171fa48b1d5_1 ... (1s) Current status: DONE

# %%
# %%bigquery
# select*from CovidItaly_staging.dpc_covid19_ita_province_20200328
# limit 5
# Out:
#                        data stato  codice_regione denominazione_regione  \
# 0 2020-03-28 17:00:00+00:00   ITA               1              Piemonte
# 1 2020-03-28 17:00:00+00:00   ITA               1              Piemonte
# 2 2020-03-28 17:00:00+00:00   ITA               1              Piemonte
# 3 2020-03-28 17:00:00+00:00   ITA               1              Piemonte
# 4 2020-03-28 17:00:00+00:00   ITA               1              Piemonte
#
#    codice_provincia denominazione_provincia sigla_provincia        lat  \
# 0                 6             Alessandria              AL  44.912974
# 1                 5                    Asti              AT  44.899129
# 2                96                  Biella              BI  45.566511
# 3                 4                   Cuneo              CN  44.393296
# 4                 3                  Novara              NO  45.445885
#
#        long  totale_casi note_it note_en
# 0  8.615401         1197    None    None
# ...
